# %%
import osmnx as ox, matplotlib.pyplot as plt
from descartes import PolygonPatch
from shapely.geometry import Polygon, MultiPolygon
ox.config(log_console=True, use_cache=True)

# %%
# get the place shape
gdf = ox.gdf_from_place('Ho Chi Minh City, Vietnam')
gdf = ox.project_gdf(gdf)

# get the street network, with retain_all=True to retain all the disconnected islands' networks
G = ox.graph_from_place('Ho Chi Minh City, Vietnam', network_type='drive', retain_all=True)
G = ox.project_graph(G)

# %%
# plot the network, but do not show it or close it yet
fig, ax = ox.plot_graph(G, fig_height=10, show=False, close=False, edge_color='#777777')

# %%
# to this matplotlib axis, add the place shape as descartes polygon patches
for geometry in gdf['geometry'].tolist():
    if isinstance(geometry, (Polygon, MultiPolygon)):
        if isinstance(geometry, Polygon):
            geometry = MultiPolygon([geometry])
        for polygon in geometry:
            patch = PolygonPatch(polygon, fc='#cccccc', ec='k', linewidth=3, alpha=0.1, zorder=-1)
            ax.add_patch(patch)

# %%
# %matplotlib inline
ox.config(log_file=True, log_console=True, use_cache=True)

city = ox.gdf_from_place('Ho Chi Minh City, Vietnam')
city
# Out:
#     bbox_east  bbox_north  bbox_south   bbox_west  \
# 0  107.027671   11.159536   10.139946  106.356716
#
#                                             geometry        place_name
# 0  POLYGON ((106.3567159 10.9916992, 106.3567711 ...  Tp HCM, Việt Nam

# %%
# optionally set up the axes extents all nicely
margin = 0.02
west, south, east, north = gdf.unary_union.bounds
margin_ns = (north - south) * margin
margin_ew = (east - west) * margin
ax.set_ylim((south - margin_ns, north + margin_ns))
ax.set_xlim((west - margin_ew, east + margin_ew))
plt.show()

# %%
#G = ox.graph_from_place('Ho Chi Minh City, Vietnam', network_type='drive')
#ox.plot_graph(ox.project_graph(G))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-27-3d82c84390cc> in <module>()
#       5
#       6 # project the geometry to the appropriate UTM zone (calculated automatically) then plot it
# ----> 7 city = ox.project_gdf(G)
#       8 fig, ax = ox.plot_shape(city)
#
# /home/user/miniconda2/lib/python2.7/site-packages/osmnx/projection.pyc in project_gdf(gdf, to_latlong)
#      68         # else, project the gdf to UTM
#      69         # if GeoDataFrame is already in UTM, just return it
# ---> 70         if (not gdf.crs is None) and ('proj' in gdf.crs) and (gdf.crs['proj'] == 'utm'):
#      71             return gdf
#      72
#
# AttributeError: 'MultiDiGraph' object has no attribute 'crs'

# %%
#ox.save_gdf_shapefile(G)

# project the geometry to the appropriate UTM zone (calculated automatically) then plot it
#city = ox.project_gdf(G)
#fig, ax = ox.plot_shape(city)

#G = ox.graph_from_place(place, network_type='drive')
#G_projected = ox.project_graph(G)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-26-b1bac33bd3fc> in <module>()
# ----> 1 ox.save_gdf_shapefile(G)
#
# /home/user/miniconda2/lib/python2.7/site-packages/osmnx/save_load.pyc in save_gdf_shapefile(gdf, filename, folder)
#      39
#      40     if filename is None:
# ---> 41         filename = make_shp_filename(gdf.gdf_name)
#      42
#      43     # give the save folder a filename subfolder to make the full path to the files
#
# AttributeError: 'MultiDiGraph' object has no attribute 'gdf_name'
