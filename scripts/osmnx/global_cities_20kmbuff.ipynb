# %%
import osmnx as ox, matplotlib.pyplot as plt
from descartes import PolygonPatch
from shapely.geometry import Polygon, MultiPolygon
ox.config(log_console=True, use_cache=True)
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-2-de4937286996> in <module>()
# ----> 1 import osmnx as ox, matplotlib.pyplot as plt
#       2 from descartes import PolygonPatch
#       3 from shapely.geometry import Polygon, MultiPolygon
#       4 ox.config(log_console=True, use_cache=True)
#
# /usr/local/lib/python2.7/dist-packages/osmnx/__init__.py in <module>()
#       6 ###################################################################################################
#       7
# ----> 8 from .core import *
#       9 from .plot import *
#      10 from .projection import *
#
# /usr/local/lib/python2.7/dist-packages/osmnx/core.py in <module>()
#      18 import numpy as np
#      19 import pandas as pd
# ---> 20 import geopandas as gpd
#      21 import networkx as nx
#      22
#
# ...

# %%
#Beijing, Jakarta, London, Los Angeles, Manila, Mexico, New Delhi, New York,Sao Paulo, Seoul, Singapore, Tokyo, Lagos,
#Nairobi, Bangalore, Ho Chi Minh

place_names = ['Ho Chi Minh City, Vietnam',
               'Beijing, China', 
               'Jakarta, Indonesia',
               'London, UK',
               'Los Angeles, California, USA',
               'Manila, Philippines',
               'Mexico City, Mexico',
               'New Delhi, India',
               'Sao Paulo, Brazil',
               'New York, New York, USA',
               'Seoul',
               'Singapore',
               'Tokyo, Japan',
               'Nairobi, Kenya',
               'Bangalore, India'
              ]

# %%
# pass in buffer_dist in meters
city_admin_20kmbuff = ox.gdf_from_place('New Haven, Connecticut, USA', gdf_name='global_cities', buffer_dist=20000)
fig, ax = ox.plot_shape(city_admin_20kmbuff)
city_admin_20kmbuff
# Out:
#    bbox_east  bbox_north  bbox_south  bbox_west  \
# 0 -72.860309    41.35039   41.246425 -72.998048
#
#                                             geometry  \
# 0  POLYGON ((-73.23588545469937 41.3311465134592,...
#
#                                           place_name
# 0  New Haven, New Haven County, Connecticut, Unit...

# %%
# save the retrieved and projected data as a shapefile
ox.save_gdf_shapefile(city_admin_20kmbuff, filename='new_haven_buff')

# %%
G = ox.graph_from_place('New Haven, Connecticut, USA', network_type='drive', retain_all=True)
G

# %%
G_projected = ox.project_graph(G)

# save street network as ESRI shapefile
ox.save_graph_shapefile(G_projected, filename='new_haven_grid')

# %%
ox.plot_graph(G_projected)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-62-b863076db753> in <module>()
#       1 ox.plot_graph(G_projected)
# ----> 2 ox.summary(G_projected)
#
# AttributeError: 'module' object has no attribute 'summary'
